# %% [markdown]
# *Variables*

# %%
import numpy as np
x=3
print(x)
# Out:
# 3

# %% [markdown]
# Variable types

# %%
# implicit declaration
k=1     # integer
y=2.0    # floating
z=1.0+0j # complex number
s="i am a string"  # string
print(k,y,z,sep=',')
# Out:
# 1,2.0,(1+0j)

# %%
# arithmetic with complex numbers
z2=0+2j
print(z+z2)
print((z+z2)/2)
# Out:
# (1+2j)
# (0.5+1j)

# %%
# arithmetic
# addition: x+y
# subtraction: x-y
# multiplication: x*y
# division: x/y
# raise to power: x**y

print(x**y)
print((z+z2)**(1/2))
# Out:
# 9.0
# (1.272019649514069+0.7861513777574233j)

# %% [markdown]
# More complicated math

# %%
theta=3.1415
np.sin(theta)
# Out:
# 9.265358966049026e-05

# %%
# you need to import the function
from numpy import sin
sin(theta)

# %%
# import mulitple functions at once
from numpy import cos,pi
sin(pi)

# %%
# import all the functions in numpy
import numpy as np
np.sin(pi)

# %%
np.log(pi)

# %%
sin(pi) # still works

# %%
log(pi) # fails
