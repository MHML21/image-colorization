# %%
# this is the librarys needed for the read in of the data, our goal is to read in colored images and 
# and turn them into black and white photos 
# inorder to do that, we are going to use opensource computer vision library



import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# Keras is an open-source software library that provides a Python interface for artificial neural networks.
# cifar is a set of 32 X 32 pixel images from the keras's dataset, and we are going to import the images
from keras.datasets import cifar10
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Dropout,Flatten
from tensorflow.keras.datasets import cifar10

# %%
(X_train,y_train),(X_test, y_test) = cifar10.load_data()

# %%
labels = ['airplane','automobile', 'bird', 'cat', 'deer', 'dog','frog', 'horse','ship','truck']

# %%
X_train_gray = np.array([cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) for image in X_train])
X_test = np.array([cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) for image in X_test])

# %%
X_train_gray = X_train_gray/255
X_train = X_train/255
X_train_gray = tf.reshape(X_train_gray, [50000, 32, 32, 1])
X_train = tf.reshape(X_train,[50000, 32, 32, 3])

# %%
print((X_train.shape))
y_train_gray_three_channel = np.zeros_like(X_train)
y_train_gray_three_channel[:,:,:,0] = X_train[:,:,:,0]
y_train_gray_three_channel[:,:,:,1] = X_train[:,:,:,0]
y_train_gray_three_channel[:,:,:,2] = X_train[:,:,:,0]
print(y_train_gray_three_channel.shape)
y_train_gray_three_channel
# Out:
# (50000, 32, 32, 3)
# (50000, 32, 32, 3)
# array([[[[0.00090734, 0.00090734, 0.00090734],
#          [0.00066128, 0.00066128, 0.00066128],
#          [0.00076894, 0.00076894, 0.00076894],
#          ...,
#          [0.00242983, 0.00242983, 0.00242983],
#          [0.00233756, 0.00233756, 0.00233756],
#          [0.00227605, 0.00227605, 0.00227605]],
#
#         [[0.00024606, 0.00024606, 0.00024606],
#          [0.        , 0.        , 0.        ],
#          [0.00027682, 0.00027682, 0.00027682],
#          ...,
#          [0.00189158, 0.00189158, 0.00189158],
#          [0.00183007, 0.00183007, 0.00183007],
#          [0.0018762 , 0.0018762 , 0.0018762 ]],
#
#         [[0.00038447, 0.00038447, 0.00038447],
#          [0.00024606, 0.00024606, 0.00024606],
#          [0.00075356, 0.00075356, 0.00075356],
#          ...,
#          [0.00181469, 0.00181469, 0.00181469],
#          [0.00184544, 0.00184544, 0.00184544],
#          [0.00167628, 0.00167628, 0.00167628]],
#
#         ...,
#
#         [[0.00319877, 0.00319877, 0.00319877],
#          [0.00309112, 0.00309112, 0.00309112],
#          [0.00304498, 0.00304498, 0.00304498],
#          ...,
#          [0.00246059, 0.00246059, 0.00246059],
#          [0.00086121, 0.00086121, 0.00086121],
#          [0.00081507, 0.00081507, 0.00081507]],
#
#         [[0.00276817, 0.00276817, 0.00276817],
#          [0.00266052, 0.00266052, 0.00266052],
#          [0.00286044, 0.00286044, 0.00286044],
#          ...,
#          [0.00282968, 0.00282968, 0.00282968],
#          [0.00149173, 0.00149173, 0.00149173],
#          [0.00127643, 0.00127643, 0.00127643]],
#
#         [[0.00272203, 0.00272203, 0.00272203],
#          [0.00258362, 0.00258362, 0.00258362],
#          [0.00275279, 0.00275279, 0.00275279],
#          ...,
#          [0.0033218 , 0.0033218 , 0.0033218 ],
#          [0.00232218, 0.00232218, 0.00232218],
#          [0.00313725, 0.00313725, 0.00313725],
#          ...,
#          [0.00269127, 0.00269127, 0.00269127],
#          [0.00264514, 0.00264514, 0.00264514],
#          [0.002599  , 0.002599  , 0.002599  ]],
#
#         ...,
#
#         [[0.00318339, 0.00318339, 0.00318339],
#          [0.00312188, 0.00312188, 0.00312188],
#          [0.00312188, 0.00312188, 0.00312188],
#          ...,
#          [0.00207612, 0.00207612, 0.00207612],
#          [0.00249135, 0.00249135, 0.00249135],
#          [0.00258362, 0.00258362, 0.00258362]],
#
#         [[0.00304498, 0.00304498, 0.00304498],
#          [0.00290657, 0.00290657, 0.00290657],
#          [0.00276817, 0.00276817, 0.00276817],
#          ...,
#          [0.00273741, 0.00273741, 0.00273741],
#          [0.00269127, 0.00269127, 0.00269127],
#          [0.00269127, 0.00269127, 0.00269127]],
#
#         [[0.00304498, 0.00304498, 0.00304498],
#          [0.00290657, 0.00290657, 0.00290657],
#          [0.00273741, 0.00273741, 0.00273741],
#          ...,
#          [0.00299885, 0.00299885, 0.00299885],
#          [0.00301423, 0.00301423, 0.00301423],
#          [0.00299885, 0.00299885, 0.00299885]]],
#
#
#        [[[0.00352172, 0.00352172, 0.00352172],
#          [0.00362937, 0.00362937, 0.00362937],
#          [0.00359862, 0.00359862, 0.00359862],
#          ...,
#          [0.00333718, 0.00333718, 0.00333718],
#          [0.00339869, 0.00339869, 0.00339869],
#          [0.00341407, 0.00341407, 0.00341407]],
#
#         [[0.00341407, 0.00341407, 0.00341407],
#          [0.00367551, 0.00367551, 0.00367551],
#          [0.00358324, 0.00358324, 0.00358324],
#          ...,
#          [0.00342945, 0.00342945, 0.00342945],
#          [0.00349097, 0.00349097, 0.00349097],
#          [0.00322953, 0.00322953, 0.00322953]],
#
#         [[0.00327566, 0.00327566, 0.00327566],
#          [0.00359862, 0.00359862, 0.00359862],
#          [0.00355248, 0.00355248, 0.00355248],
#          ...,
#          [0.00338331, 0.00338331, 0.00338331],
#          [0.00338331, 0.00338331, 0.00338331],
#          [0.0031065 , 0.0031065 , 0.0031065 ]],
#
#         ...,
#
#         [[0.00230681, 0.00230681, 0.00230681],
#          [0.00215302, 0.00215302, 0.00215302],
#          [0.00202999, 0.00202999, 0.00202999],
#          ...,
#          [0.00344483, 0.00344483, 0.00344483],
#          [0.0035371 , 0.0035371 , 0.0035371 ],
#          [0.00370627, 0.00370627, 0.00370627]],
#
#         [[0.00210688, 0.00210688, 0.00210688],
#          [0.00199923, 0.00199923, 0.00199923],
#          [0.00192234, 0.00192234, 0.00192234],
#          ...,
#          [0.00278354, 0.00278354, 0.00278354],
#          [0.0031065 , 0.0031065 , 0.0031065 ],
#          [0.00326028, 0.00326028, 0.00326028]],
#
#         [[0.0018762 , 0.0018762 , 0.0018762 ],
#          [0.00181469, 0.00181469, 0.00181469],
#          [0.00184544, 0.00184544, 0.00184544],
#          ...,
#          [0.00275279, 0.00275279, 0.00275279],
#          [0.00252211, 0.00252211, 0.00252211],
#          [0.00250673, 0.00250673, 0.00250673]]]])
